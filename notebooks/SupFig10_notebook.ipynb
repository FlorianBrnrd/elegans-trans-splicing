# %% [markdown]
# # Supplementary Figure 10

# %% [markdown]
# ---

# %% [markdown]
# <br>

# %% [markdown]
# ## Import libraries

# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

# %% [markdown]
# ## Settings for saving figures as pdf

# %%
mpl.rcParams['pdf.fonttype'] = 42
mpl.rcParams['ps.fonttype'] = 42

# %% [markdown]
# ## Set environmental constants

# %%
# Set path where files are stored
path = '/Volumes/elegans/rna_sequencing'

# %% [markdown]
# ## Opening Dataset file

# %%
# Open dataset generated as part of the pre-processing step
dataset = pd.read_csv(f'{path}/dataset_+SSP+SL+HAIRPIN.tsv', sep='\t')

# %% [markdown]
# ---

# %% [markdown]
# <br>

# %% [markdown]
# # Panel: High confidence SL matches are located near the alignment start

# %%
# %matplotlib inline
sns.set_style('ticks')
fig, ax = plt.subplots(nrows=2, ncols=1, figsize=(8,6), sharex=True, dpi=150)

# high confidence SL match (score > 15)
high = dataset[dataset['SL_score'] > 15]['SL_distance'] #.apply(lambda x: -x if x>=0 else 0)
ax[0].hist(high, bins=[i for i in range(-100,1,1)], color='#d9d7d7',edgecolor = "k", linewidth=0.5)
ax[0].set_ylabel('Number of reads')

# low confidence SL match (score < 10)
low = dataset[dataset['SL_score'] < 10]['SL_distance'] #.apply(lambda x: -x if x>=0 else 0)
ax[1].hist(low, bins=[i for i in range(-100,1,1)], color='#d9d7d7',edgecolor = "k", linewidth=0.5)
ax[1].set_ylabel('Number of reads')
ax[1].set_xlabel('SL distance to alignment start (nt)')

# plots settings
plt.xlim(-101,0)

# save
plt.savefig('SupFig10-SL_distance_to_alignment_start.pdf', dpi=800, bbox_inches='tight')

# %% [markdown]
# <font size="4">**Sup. Fig. 10:**<br></font>
# High confidence SL matches are preferentially located near the alignment start. For each SL
# sequence identified, we measured their distance to the alignment start. As expected, matches which scored high
# (top panel) are found in the direct vicinity of the alignment start. Low-scoring matches (bottom panel) are generally
# found all across the 5’ soft-clip region, but a sub-set of those are found where expected making those more
# reliable.
